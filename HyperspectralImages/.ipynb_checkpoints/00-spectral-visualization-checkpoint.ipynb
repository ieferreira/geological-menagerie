# %%
import scipy.io
import matplotlib.pyplot as plt

mat = scipy.io.loadmat('data/Indian_pines_corrected.mat')

# %%
type(mat)
# Out:
# dict

# %%
hsi_img = mat["indian_pines_corrected"]

# %%
hsi_img.shape
# Out:
# (145, 145, 200)

# %%
plt.imshow(hsi_img[:,:,0])

# %%
from ipywidgets import interact

@interact(num= (0,144,10))
def plot_img(num):
    plt.imshow(hsi_img[:,:,num])
    plt.show()
# Out:
# interactive(children=(IntSlider(value=70, description='num', max=144, step=10), Output()), _dom_classes=('widg…

# %%
hsi_img[1]
# Out:
# array([[2576, 4388, 4334, ..., 1047, 1030, 1006],
#        [2747, 4264, 4592, ..., 1055, 1039, 1015],
#        [2750, 4268, 4423, ..., 1047, 1026, 1015],
#        ...,
#        [3859, 4512, 4605, ..., 1056, 1035, 1015],
#        [3686, 4264, 4690, ..., 1051, 1012, 1020],
#        [2744, 4268, 4597, ..., 1047, 1019, 1016]], dtype=uint16)

# %%
type(mat["indian_pines_corrected"])
# Out:
# numpy.ndarray

# %%
@interact(num= (0,144,10))
def plot_img(num):
    plt.imshow(hsi_img[:,:,num],cmap="jet")
    plt.show()
# Out:
# interactive(children=(IntSlider(value=70, description='num', max=144, step=10), Output()), _dom_classes=('widg…

# %%
import spectral as sl

# %%
view = sl.imshow(hsi_img)

# %%
sl.view_cube(hsi_img, bands=[29, 19, 9])
# Out:
# C:\Users\ferreira\anaconda3\lib\site-packages\spectral\graphics\graphics.py:757: UserWarning:
# There is no current wx.App object - creating one now.
#   warnings.warn('\nThere is no current wx.App object - creating one now.',
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\spectral\graphics\hypercube.py in on_resize(self, event)
#     446             self.Show()
#     447             size = self.canvas.GetClientSize()
# --> 448             self.resize(size.width, size.height)
#     449             self.canvas.Refresh(False)
#     450         event.Skip()
#
# ~\anaconda3\lib\site-packages\spectral\graphics\hypercube.py in resize(self, width, height)
#     452     def resize(self, width, height):
#     453         """Reshape the OpenGL viewport based on dimensions of the window."""
# --> 454         import OpenGL.GL as gl
#     455         import OpenGL.GLU as glu
#     456         self.size = (width, height)
#
# ModuleNotFoundError: No module named 'OpenGL'
