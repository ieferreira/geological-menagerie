# %%
import scipy.io
import matplotlib.pyplot as plt

mat = scipy.io.loadmat('data/Indian_pines_corrected.mat')
mat2 = scipy.io.loadmat('data/Salinas_corrected.mat')

# %%
type(mat)
# Out:
# dict

# %%
hsi_img = mat["indian_pines_corrected"]
hsi_salinas = mat2["salinas_corrected"]

# %%
hsi_img.shape
# Out:
# (145, 145, 200)

# %%
plt.imshow(hsi_img[:,:,0])

# %%
from ipywidgets import interact

@interact(num= (0,144,10))
def plot_img(num):
    plt.imshow(hsi_img[:,:,num])
    plt.show()
# Out:
# interactive(children=(IntSlider(value=70, description='num', max=144, step=10), Output()), _dom_classes=('widg…

# %%
hsi_img[1]
# Out:
# array([[2576, 4388, 4334, ..., 1047, 1030, 1006],
#        [2747, 4264, 4592, ..., 1055, 1039, 1015],
#        [2750, 4268, 4423, ..., 1047, 1026, 1015],
#        ...,
#        [3859, 4512, 4605, ..., 1056, 1035, 1015],
#        [3686, 4264, 4690, ..., 1051, 1012, 1020],
#        [2744, 4268, 4597, ..., 1047, 1019, 1016]], dtype=uint16)

# %%
type(mat["indian_pines_corrected"])
# Out:
# numpy.ndarray

# %%
@interact(num= (0,204,10))
def plot_img(num):
    plt.imshow(hsi_salinas[:,:,num],cmap="jet")
    plt.show()
# Out:
# interactive(children=(IntSlider(value=100, description='num', max=204, step=10), Output()), _dom_classes=('wid…

# %%
import matplotlib.pyplot as plt

plt.plot(hsi_salinas[0,:,0])

# %%
import spectral as sl

# %%
view = sl.imshow(hsi_img[:,0,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b22d043eb98c> in <module>
# ----> 1 view = sl.imshow(hsi_img[:,0,:])
#
# NameError: name 'sl' is not defined

# %%
pc = sl.principal_components(hsi_img)

# %%
xdata = pc.transform(hsi_img)

# %%
@interact(num= (0,144,10))
plot_img(num):
    plt.imshow(hsi_img[:,:,num],cmap="jet")
    plt.show()
