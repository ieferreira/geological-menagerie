# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from skimage.transform import hough_line, hough_line_peaks
from skimage.draw import line
# plotting modules
from PIL import Image 
import matplotlib.pyplot as plt
from utilities import *
#from matplotlib import cm, colors
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
im = load_im("cleavageGarnet.jpg")
plt.imshow(im)

# %%
tested_angles = np.linspace(-np.pi / 2, np.pi / 2, 180, endpoint=False)
out, angles, d = hough_line(im)
plot_hough(im, out, angles, d)

# %%
im = load_im("faultOutcrop.jpg")
plt.imshow(im)

# %%
tested_angles = np.linspace(-np.pi / 2, np.pi / 2, 36, endpoint=False)
out, angles, d = hough_line(im, tested_angles)
plot_hough(im, out, angles, d)
